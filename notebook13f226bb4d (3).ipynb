# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/helmet-detection/annotations/BikesHelmets338.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets680.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets62.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets172.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets622.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets477.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets488.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets696.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets71.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets269.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets206.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets705.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets515.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets113.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets546.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets632.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets267.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets379.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets387.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets545.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets201.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets5.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets483.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets49.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets490.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets363.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets606.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets614.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets612.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets218.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets745.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets699.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets131.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets652.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets222.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets712.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets241.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets11.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets543.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets318.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets692.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets373.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets111.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets227.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets736.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets760.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets565.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets217.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets189.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets316.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets438.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets572.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets55.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets129.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets119.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets52.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets591.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets501.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets716.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets191.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets642.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets733.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets629.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets348.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets9.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets202.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets246.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets725.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets618.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets698.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets130.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets397.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets735.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets582.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets159.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets393.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets547.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets564.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets476.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets281.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets4.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets245.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets751.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets155.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets495.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets126.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets702.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets326.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets239.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets526.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets45.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets577.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets492.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets92.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets356.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets3.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets706.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets441.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets44.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets34.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets681.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets244.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets624.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets552.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets608.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets402.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets729.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets469.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets621.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets141.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets85.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets263.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets215.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets157.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets414.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets734.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets325.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets347.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets145.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets137.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets337.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets523.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets669.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets512.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets520.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets743.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets741.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets251.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets238.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets25.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets463.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets148.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets250.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets322.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets61.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets216.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets288.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets630.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets718.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets420.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets657.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets117.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets528.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets553.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets628.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets341.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets613.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets160.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets675.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets559.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets668.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets449.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets676.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets378.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets91.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets634.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets756.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets176.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets571.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets108.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets140.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets761.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets229.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets372.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets667.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets228.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets340.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets248.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets41.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets626.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets371.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets274.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets303.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets494.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets365.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets436.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets391.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets311.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets283.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets180.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets421.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets451.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets366.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets384.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets426.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets291.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets30.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets188.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets562.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets762.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets580.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets150.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets427.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets314.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets447.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets456.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets732.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets446.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets576.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets195.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets417.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets31.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets370.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets458.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets561.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets418.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets240.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets110.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets670.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets583.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets349.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets518.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets462.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets731.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets557.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets105.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets396.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets380.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets156.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets139.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets609.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets468.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets298.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets713.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets467.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets350.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets739.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets296.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets231.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets152.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets432.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets321.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets173.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets226.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets759.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets509.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets286.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets752.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets143.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets310.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets392.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets368.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets0.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets664.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets478.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets548.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets737.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets89.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets280.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets68.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets167.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets242.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets400.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets271.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets443.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets532.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets7.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets161.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets273.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets260.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets461.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets531.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets230.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets70.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets386.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets327.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets290.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets39.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets178.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets534.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets270.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets649.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets198.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets627.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets144.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets81.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets276.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets625.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets97.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets416.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets610.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets120.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets346.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets162.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets671.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets285.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets166.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets287.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets484.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets598.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets304.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets711.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets682.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets566.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets194.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets234.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets689.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets597.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets489.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets203.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets84.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets100.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets128.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets225.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets567.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets691.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets146.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets684.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets268.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets394.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets168.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets106.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets344.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets8.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets605.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets485.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets336.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets758.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets181.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets132.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets554.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets472.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets127.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets359.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets747.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets324.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets542.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets519.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets261.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets79.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets574.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets504.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets641.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets20.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets444.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets2.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets486.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets754.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets377.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets360.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets585.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets86.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets243.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets714.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets164.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets171.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets663.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets210.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets474.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets723.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets497.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets677.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets701.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets125.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets704.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets487.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets764.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets707.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets24.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets645.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets514.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets475.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets448.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets390.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets47.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets434.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets200.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets87.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets740.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets687.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets219.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets220.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets297.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets362.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets266.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets169.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets252.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets620.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets278.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets423.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets533.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets685.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets40.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets424.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets116.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets480.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets506.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets529.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets313.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets253.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets302.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets115.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets10.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets422.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets76.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets428.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets660.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets439.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets6.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets358.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets256.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets603.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets320.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets375.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets114.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets541.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets23.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets300.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets364.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets535.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets615.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets299.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets709.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets703.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets623.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets99.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets57.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets525.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets665.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets75.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets573.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets508.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets481.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets398.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets505.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets133.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets1.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets405.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets95.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets199.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets727.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets208.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets466.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets401.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets479.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets540.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets330.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets42.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets151.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets407.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets122.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets459.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets154.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets98.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets249.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets437.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets88.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets32.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets345.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets498.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets103.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets317.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets653.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets123.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets410.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets232.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets134.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets13.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets666.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets464.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets96.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets187.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets73.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets662.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets205.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets395.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets192.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets595.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets211.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets537.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets500.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets147.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets738.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets728.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets58.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets165.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets236.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets411.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets247.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets412.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets600.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets118.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets619.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets581.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets460.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets301.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets507.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets568.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets26.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets15.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets353.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets604.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets719.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets655.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets686.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets502.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets46.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets142.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets383.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets408.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets153.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets213.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets527.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets695.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets323.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets149.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets746.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets536.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets596.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets204.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets315.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets12.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets636.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets223.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets342.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets496.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets254.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets429.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets517.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets648.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets37.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets637.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets185.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets415.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets516.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets374.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets750.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets674.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets289.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets617.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets138.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets102.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets651.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets212.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets635.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets539.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets690.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets643.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets720.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets77.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets64.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets307.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets233.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets101.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets433.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets63.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets284.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets74.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets67.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets556.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets661.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets570.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets399.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets631.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets584.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets544.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets616.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets104.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets14.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets700.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets258.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets599.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets594.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets431.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets658.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets90.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets730.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets678.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets207.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets43.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets272.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets470.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets607.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets538.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets452.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets482.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets282.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets558.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets177.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets376.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets294.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets647.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets601.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets656.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets646.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets19.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets197.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets688.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets672.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets17.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets419.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets435.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets524.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets193.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets306.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets69.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets430.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets644.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets72.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets578.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets275.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets259.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets16.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets633.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets757.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets332.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets163.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets471.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets361.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets224.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets749.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets530.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets21.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets184.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets455.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets94.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets659.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets170.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets158.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets560.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets308.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets694.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets334.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets355.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets551.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets724.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets331.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets107.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets277.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets611.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets493.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets196.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets221.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets179.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets654.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets453.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets29.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets51.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets722.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets175.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets295.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets673.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets262.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets503.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets457.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets186.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets257.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets563.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets82.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets333.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets522.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets589.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets602.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets404.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets592.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets440.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets406.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets352.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets190.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets78.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets292.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets693.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets124.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets214.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets588.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets60.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets255.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets136.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets309.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets683.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets748.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets550.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets237.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets354.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets442.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets638.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets450.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets593.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets121.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets329.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets343.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets513.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets382.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets409.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets569.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets385.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets48.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets715.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets579.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets369.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets335.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets389.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets264.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets717.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets454.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets510.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets112.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets721.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets174.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets135.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets381.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets38.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets27.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets640.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets209.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets80.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets753.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets319.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets265.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets36.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets575.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets710.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets182.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets53.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets413.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets511.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets235.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets726.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets367.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets59.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets66.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets590.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets351.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets586.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets555.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets403.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets56.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets339.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets650.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets33.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets445.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets587.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets765.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets35.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets697.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets93.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets293.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets708.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets28.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets499.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets279.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets183.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets425.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets491.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets388.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets679.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets473.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets744.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets763.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets305.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets755.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets357.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets465.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets521.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets742.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets549.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets65.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets18.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets639.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets22.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets83.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets328.xml
# /kaggle/input/helmet-detection/annotations/BikesHelmets109.xml
# ...
# /kaggle/input/helmet-detection/images/BikesHelmets721.png
# /kaggle/input/helmet-detection/images/BikesHelmets515.png
# /kaggle/input/helmet-detection/images/BikesHelmets382.png
# /kaggle/input/helmet-detection/images/BikesHelmets611.png
# /kaggle/input/helmet-detection/images/BikesHelmets169.png
# /kaggle/input/helmet-detection/images/BikesHelmets501.png
# /kaggle/input/helmet-detection/images/BikesHelmets94.png
# /kaggle/input/helmet-detection/images/BikesHelmets56.png
# /kaggle/input/helmet-detection/images/BikesHelmets449.png
# /kaggle/input/helmet-detection/images/BikesHelmets654.png
# /kaggle/input/helmet-detection/images/BikesHelmets386.png
# /kaggle/input/helmet-detection/images/BikesHelmets615.png
# /kaggle/input/helmet-detection/images/BikesHelmets224.png
# /kaggle/input/helmet-detection/images/BikesHelmets249.png
# /kaggle/input/helmet-detection/images/BikesHelmets758.png
# /kaggle/input/helmet-detection/images/BikesHelmets682.png
# /kaggle/input/helmet-detection/images/BikesHelmets536.png
# /kaggle/input/helmet-detection/images/BikesHelmets339.png
# /kaggle/input/helmet-detection/images/BikesHelmets233.png
# /kaggle/input/helmet-detection/images/BikesHelmets192.png
# /kaggle/input/helmet-detection/images/BikesHelmets709.png
# /kaggle/input/helmet-detection/images/BikesHelmets68.png
# /kaggle/input/helmet-detection/images/BikesHelmets490.png
# /kaggle/input/helmet-detection/images/BikesHelmets523.png
# /kaggle/input/helmet-detection/images/BikesHelmets586.png
# /kaggle/input/helmet-detection/images/BikesHelmets5.png
# /kaggle/input/helmet-detection/images/BikesHelmets38.png
# /kaggle/input/helmet-detection/images/BikesHelmets661.png
# /kaggle/input/helmet-detection/images/BikesHelmets105.png
# /kaggle/input/helmet-detection/images/BikesHelmets460.png
# /kaggle/input/helmet-detection/images/BikesHelmets416.png
# /kaggle/input/helmet-detection/images/BikesHelmets589.png
# /kaggle/input/helmet-detection/images/BikesHelmets357.png
# /kaggle/input/helmet-detection/images/BikesHelmets675.png
# /kaggle/input/helmet-detection/images/BikesHelmets520.png
# /kaggle/input/helmet-detection/images/BikesHelmets755.png
# /kaggle/input/helmet-detection/images/BikesHelmets647.png
# /kaggle/input/helmet-detection/images/BikesHelmets704.png
# /kaggle/input/helmet-detection/images/BikesHelmets692.png
# /kaggle/input/helmet-detection/images/BikesHelmets587.png
# /kaggle/input/helmet-detection/images/BikesHelmets652.png
# /kaggle/input/helmet-detection/images/BikesHelmets14.png
# /kaggle/input/helmet-detection/images/BikesHelmets22.png
# /kaggle/input/helmet-detection/images/BikesHelmets557.png
# /kaggle/input/helmet-detection/images/BikesHelmets345.png
# /kaggle/input/helmet-detection/images/BikesHelmets352.png
# /kaggle/input/helmet-detection/images/BikesHelmets414.png
# /kaggle/input/helmet-detection/images/BikesHelmets47.png
# /kaggle/input/helmet-detection/images/BikesHelmets6.png
# /kaggle/input/helmet-detection/images/BikesHelmets139.png
# /kaggle/input/helmet-detection/images/BikesHelmets605.png
# /kaggle/input/helmet-detection/images/BikesHelmets325.png
# /kaggle/input/helmet-detection/images/BikesHelmets205.png
# /kaggle/input/helmet-detection/images/BikesHelmets407.png
# /kaggle/input/helmet-detection/images/BikesHelmets432.png
# /kaggle/input/helmet-detection/images/BikesHelmets245.png
# /kaggle/input/helmet-detection/images/BikesHelmets248.png
# /kaggle/input/helmet-detection/images/BikesHelmets532.png
# /kaggle/input/helmet-detection/images/BikesHelmets367.png
# /kaggle/input/helmet-detection/images/BikesHelmets727.png
# /kaggle/input/helmet-detection/images/BikesHelmets684.png
# /kaggle/input/helmet-detection/images/BikesHelmets143.png
# /kaggle/input/helmet-detection/images/BikesHelmets256.png
# /kaggle/input/helmet-detection/images/BikesHelmets387.png
# /kaggle/input/helmet-detection/images/BikesHelmets320.png
# /kaggle/input/helmet-detection/images/BikesHelmets297.png
# /kaggle/input/helmet-detection/images/BikesHelmets90.png
# /kaggle/input/helmet-detection/images/BikesHelmets696.png
# /kaggle/input/helmet-detection/images/BikesHelmets648.png
# /kaggle/input/helmet-detection/images/BikesHelmets422.png
# /kaggle/input/helmet-detection/images/BikesHelmets578.png
# /kaggle/input/helmet-detection/images/BikesHelmets502.png
# /kaggle/input/helmet-detection/images/BikesHelmets191.png
# /kaggle/input/helmet-detection/images/BikesHelmets518.png
# /kaggle/input/helmet-detection/images/BikesHelmets522.png
# /kaggle/input/helmet-detection/images/BikesHelmets282.png
# /kaggle/input/helmet-detection/images/BikesHelmets617.png
# /kaggle/input/helmet-detection/images/BikesHelmets270.png
# /kaggle/input/helmet-detection/images/BikesHelmets441.png
# /kaggle/input/helmet-detection/images/BikesHelmets276.png
# /kaggle/input/helmet-detection/images/BikesHelmets726.png
# /kaggle/input/helmet-detection/images/BikesHelmets494.png
# /kaggle/input/helmet-detection/images/BikesHelmets321.png
# /kaggle/input/helmet-detection/images/BikesHelmets544.png
# /kaggle/input/helmet-detection/images/BikesHelmets222.png
# /kaggle/input/helmet-detection/images/BikesHelmets136.png
# /kaggle/input/helmet-detection/images/BikesHelmets602.png
# /kaggle/input/helmet-detection/images/BikesHelmets83.png
# /kaggle/input/helmet-detection/images/BikesHelmets262.png
# /kaggle/input/helmet-detection/images/BikesHelmets504.png
# /kaggle/input/helmet-detection/images/BikesHelmets562.png
# /kaggle/input/helmet-detection/images/BikesHelmets531.png
# /kaggle/input/helmet-detection/images/BikesHelmets209.png
# /kaggle/input/helmet-detection/images/BikesHelmets639.png
# /kaggle/input/helmet-detection/images/BikesHelmets421.png
# /kaggle/input/helmet-detection/images/BikesHelmets42.png
# /kaggle/input/helmet-detection/images/BikesHelmets318.png
# /kaggle/input/helmet-detection/images/BikesHelmets168.png
# /kaggle/input/helmet-detection/images/BikesHelmets174.png
# /kaggle/input/helmet-detection/images/BikesHelmets307.png
# /kaggle/input/helmet-detection/images/BikesHelmets410.png
# /kaggle/input/helmet-detection/images/BikesHelmets508.png
# /kaggle/input/helmet-detection/images/BikesHelmets300.png
# /kaggle/input/helmet-detection/images/BikesHelmets399.png
# /kaggle/input/helmet-detection/images/BikesHelmets525.png
# /kaggle/input/helmet-detection/images/BikesHelmets751.png
# /kaggle/input/helmet-detection/images/BikesHelmets428.png
# /kaggle/input/helmet-detection/images/BikesHelmets610.png
# /kaggle/input/helmet-detection/images/BikesHelmets52.png
# /kaggle/input/helmet-detection/images/BikesHelmets108.png
# /kaggle/input/helmet-detection/images/BikesHelmets35.png
# /kaggle/input/helmet-detection/images/BikesHelmets728.png
# /kaggle/input/helmet-detection/images/BikesHelmets323.png
# /kaggle/input/helmet-detection/images/BikesHelmets514.png
# /kaggle/input/helmet-detection/images/BikesHelmets633.png
# /kaggle/input/helmet-detection/images/BikesHelmets7.png
# /kaggle/input/helmet-detection/images/BikesHelmets750.png
# /kaggle/input/helmet-detection/images/BikesHelmets55.png
# /kaggle/input/helmet-detection/images/BikesHelmets84.png
# /kaggle/input/helmet-detection/images/BikesHelmets200.png
# /kaggle/input/helmet-detection/images/BikesHelmets372.png
# /kaggle/input/helmet-detection/images/BikesHelmets102.png
# /kaggle/input/helmet-detection/images/BikesHelmets509.png
# /kaggle/input/helmet-detection/images/BikesHelmets177.png
# /kaggle/input/helmet-detection/images/BikesHelmets298.png
# /kaggle/input/helmet-detection/images/BikesHelmets294.png
# /kaggle/input/helmet-detection/images/BikesHelmets753.png
# /kaggle/input/helmet-detection/images/BikesHelmets350.png
# /kaggle/input/helmet-detection/images/BikesHelmets354.png
# /kaggle/input/helmet-detection/images/BikesHelmets454.png
# /kaggle/input/helmet-detection/images/BikesHelmets77.png
# /kaggle/input/helmet-detection/images/BikesHelmets44.png
# /kaggle/input/helmet-detection/images/BikesHelmets720.png
# /kaggle/input/helmet-detection/images/BikesHelmets623.png
# /kaggle/input/helmet-detection/images/BikesHelmets680.png
# /kaggle/input/helmet-detection/images/BikesHelmets666.png
# /kaggle/input/helmet-detection/images/BikesHelmets92.png
# /kaggle/input/helmet-detection/images/BikesHelmets344.png
# /kaggle/input/helmet-detection/images/BikesHelmets87.png
# /kaggle/input/helmet-detection/images/BikesHelmets535.png
# /kaggle/input/helmet-detection/images/BikesHelmets561.png
# /kaggle/input/helmet-detection/images/BikesHelmets448.png
# /kaggle/input/helmet-detection/images/BikesHelmets375.png
# /kaggle/input/helmet-detection/images/BikesHelmets687.png
# /kaggle/input/helmet-detection/images/BikesHelmets71.png
# /kaggle/input/helmet-detection/images/BikesHelmets211.png
# /kaggle/input/helmet-detection/images/BikesHelmets476.png
# /kaggle/input/helmet-detection/images/BikesHelmets640.png
# /kaggle/input/helmet-detection/images/BikesHelmets203.png
# /kaggle/input/helmet-detection/images/BikesHelmets348.png
# /kaggle/input/helmet-detection/images/BikesHelmets259.png
# /kaggle/input/helmet-detection/images/BikesHelmets63.png
# /kaggle/input/helmet-detection/images/BikesHelmets165.png
# /kaggle/input/helmet-detection/images/BikesHelmets710.png
# /kaggle/input/helmet-detection/images/BikesHelmets182.png
# /kaggle/input/helmet-detection/images/BikesHelmets468.png
# /kaggle/input/helmet-detection/images/BikesHelmets133.png
# /kaggle/input/helmet-detection/images/BikesHelmets739.png
# /kaggle/input/helmet-detection/images/BikesHelmets132.png
# /kaggle/input/helmet-detection/images/BikesHelmets636.png
# /kaggle/input/helmet-detection/images/BikesHelmets690.png
# /kaggle/input/helmet-detection/images/BikesHelmets492.png
# /kaggle/input/helmet-detection/images/BikesHelmets299.png
# /kaggle/input/helmet-detection/images/BikesHelmets195.png
# /kaggle/input/helmet-detection/images/BikesHelmets380.png
# /kaggle/input/helmet-detection/images/BikesHelmets24.png
# /kaggle/input/helmet-detection/images/BikesHelmets395.png
# /kaggle/input/helmet-detection/images/BikesHelmets662.png
# /kaggle/input/helmet-detection/images/BikesHelmets461.png
# /kaggle/input/helmet-detection/images/BikesHelmets659.png
# /kaggle/input/helmet-detection/images/BikesHelmets565.png
# /kaggle/input/helmet-detection/images/BikesHelmets146.png
# /kaggle/input/helmet-detection/images/BikesHelmets415.png
# /kaggle/input/helmet-detection/images/BikesHelmets554.png
# /kaggle/input/helmet-detection/images/BikesHelmets498.png
# /kaggle/input/helmet-detection/images/BikesHelmets691.png
# /kaggle/input/helmet-detection/images/BikesHelmets603.png
# /kaggle/input/helmet-detection/images/BikesHelmets681.png
# /kaggle/input/helmet-detection/images/BikesHelmets353.png
# /kaggle/input/helmet-detection/images/BikesHelmets15.png
# /kaggle/input/helmet-detection/images/BikesHelmets234.png
# /kaggle/input/helmet-detection/images/BikesHelmets78.png
# /kaggle/input/helmet-detection/images/BikesHelmets156.png
# /kaggle/input/helmet-detection/images/BikesHelmets614.png
# /kaggle/input/helmet-detection/images/BikesHelmets10.png
# /kaggle/input/helmet-detection/images/BikesHelmets458.png
# /kaggle/input/helmet-detection/images/BikesHelmets167.png
# /kaggle/input/helmet-detection/images/BikesHelmets280.png
# /kaggle/input/helmet-detection/images/BikesHelmets241.png
# /kaggle/input/helmet-detection/images/BikesHelmets250.png
# /kaggle/input/helmet-detection/images/BikesHelmets653.png
# /kaggle/input/helmet-detection/images/BikesHelmets8.png
# /kaggle/input/helmet-detection/images/BikesHelmets74.png
# /kaggle/input/helmet-detection/images/BikesHelmets559.png
# /kaggle/input/helmet-detection/images/BikesHelmets657.png
# /kaggle/input/helmet-detection/images/BikesHelmets722.png
# /kaggle/input/helmet-detection/images/BikesHelmets597.png
# /kaggle/input/helmet-detection/images/BikesHelmets144.png
# /kaggle/input/helmet-detection/images/BikesHelmets242.png
# /kaggle/input/helmet-detection/images/BikesHelmets149.png
# /kaggle/input/helmet-detection/images/BikesHelmets322.png
# /kaggle/input/helmet-detection/images/BikesHelmets425.png
# /kaggle/input/helmet-detection/images/BikesHelmets60.png
# /kaggle/input/helmet-detection/images/BikesHelmets154.png
# /kaggle/input/helmet-detection/images/BikesHelmets638.png
# /kaggle/input/helmet-detection/images/BikesHelmets606.png
# /kaggle/input/helmet-detection/images/BikesHelmets577.png
# /kaggle/input/helmet-detection/images/BikesHelmets591.png
# /kaggle/input/helmet-detection/images/BikesHelmets723.png
# /kaggle/input/helmet-detection/images/BikesHelmets208.png
# /kaggle/input/helmet-detection/images/BikesHelmets665.png
# /kaggle/input/helmet-detection/images/BikesHelmets51.png
# /kaggle/input/helmet-detection/images/BikesHelmets533.png
# /kaggle/input/helmet-detection/images/BikesHelmets147.png
# /kaggle/input/helmet-detection/images/BikesHelmets176.png
# /kaggle/input/helmet-detection/images/BikesHelmets313.png
# /kaggle/input/helmet-detection/images/BikesHelmets549.png
# /kaggle/input/helmet-detection/images/BikesHelmets274.png
# /kaggle/input/helmet-detection/images/BikesHelmets688.png
# /kaggle/input/helmet-detection/images/BikesHelmets485.png
# /kaggle/input/helmet-detection/images/BikesHelmets9.png
# /kaggle/input/helmet-detection/images/BikesHelmets503.png
# /kaggle/input/helmet-detection/images/BikesHelmets223.png
# /kaggle/input/helmet-detection/images/BikesHelmets255.png
# /kaggle/input/helmet-detection/images/BikesHelmets210.png
# /kaggle/input/helmet-detection/images/BikesHelmets475.png
# /kaggle/input/helmet-detection/images/BikesHelmets730.png
# /kaggle/input/helmet-detection/images/BikesHelmets338.png
# /kaggle/input/helmet-detection/images/BikesHelmets216.png
# /kaggle/input/helmet-detection/images/BikesHelmets369.png
# /kaggle/input/helmet-detection/images/BikesHelmets477.png
# /kaggle/input/helmet-detection/images/BikesHelmets175.png
# /kaggle/input/helmet-detection/images/BikesHelmets442.png
# /kaggle/input/helmet-detection/images/BikesHelmets379.png
# /kaggle/input/helmet-detection/images/BikesHelmets279.png
# /kaggle/input/helmet-detection/images/BikesHelmets472.png
# /kaggle/input/helmet-detection/images/BikesHelmets302.png
# /kaggle/input/helmet-detection/images/BikesHelmets510.png
# /kaggle/input/helmet-detection/images/BikesHelmets604.png
# /kaggle/input/helmet-detection/images/BikesHelmets72.png
# /kaggle/input/helmet-detection/images/BikesHelmets761.png
# /kaggle/input/helmet-detection/images/BikesHelmets65.png
# /kaggle/input/helmet-detection/images/BikesHelmets263.png
# /kaggle/input/helmet-detection/images/BikesHelmets708.png
# /kaggle/input/helmet-detection/images/BikesHelmets188.png
# /kaggle/input/helmet-detection/images/BikesHelmets694.png
# /kaggle/input/helmet-detection/images/BikesHelmets486.png
# /kaggle/input/helmet-detection/images/BikesHelmets499.png
# /kaggle/input/helmet-detection/images/BikesHelmets232.png
# /kaggle/input/helmet-detection/images/BikesHelmets312.png
# /kaggle/input/helmet-detection/images/BikesHelmets538.png
# /kaggle/input/helmet-detection/images/BikesHelmets30.png
# /kaggle/input/helmet-detection/images/BikesHelmets396.png
# /kaggle/input/helmet-detection/images/BikesHelmets762.png
# /kaggle/input/helmet-detection/images/BikesHelmets337.png
# /kaggle/input/helmet-detection/images/BikesHelmets304.png
# /kaggle/input/helmet-detection/images/BikesHelmets724.png
# /kaggle/input/helmet-detection/images/BikesHelmets540.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results__.html
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__notebook__.ipynb
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__output__.json
# /kaggle/input/k/abdallahsharkawy/helmet-detection/custom.css
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___9_0.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___9_1.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___9_2.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___14_0.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___12_0.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___2_0.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___6_0.png
# /kaggle/input/k/abdallahsharkawy/helmet-detection/__results___files/__results___9_3.png
# /kaggle/input/my-test-images/one.jpg
# /kaggle/input/my-test-images2/two.jpg

# %%
import cv2
import matplotlib.pyplot as plt
import os

# Define dataset path
DATASET_DIR = '/kaggle/input/helmet-detection'
image_dir = os.path.join(DATASET_DIR, 'images')

# List all images in the dataset directory (this will handle multiple images)
image_files = os.listdir(image_dir)
if len(image_files) > 0:
    image_file = image_files[0]  # Choose the first image for display
else:
    print("No images found in the dataset directory.")
    image_file = ''

# Ensure image file is valid and load it
if image_file:
    image_path = os.path.join(image_dir, image_file)
    image = cv2.imread(image_path)
    if image is None:
        print("Failed to load image:", image_path)
    else:
        # Convert from BGR to RGB for proper display
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        plt.imshow(image)
        plt.title(image_file)
        plt.axis('off')
        plt.show()

# %%
import cv2
import numpy as np
import random

def preprocess_image(image, target_size=(256, 256), augment=True):
    """
    Applies preprocessing and enhancement steps to an input image.
    
    Parameters:
        image (numpy array): Input image in RGB format.
        target_size (tuple): Desired size (width, height) for resizing.
        augment (bool): Whether to apply image augmentation.
        
    Returns:
        preprocessed_image (numpy array): Final processed image.
    """
    # 1. Resize
    resized = cv2.resize(image, target_size)
    # 2. Gaussian Blur (Noise Reduction)
    blurred = cv2.GaussianBlur(resized, (5, 5), 0)

    # 3. Contrast Adjustment using CLAHE (on L channel in LAB)
    lab = cv2.cvtColor(blurred, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    l_clahe = clahe.apply(l)
    lab_clahe = cv2.merge((l_clahe, a, b))
    contrast_adjusted = cv2.cvtColor(lab_clahe, cv2.COLOR_LAB2RGB)

    # 4. Sharpening Filter
    sharpen_kernel = np.array([[0, -1, 0],
                               [-1, 5,-1],
                               [0, -1, 0]])
    sharpened = cv2.filter2D(contrast_adjusted, -1, sharpen_kernel)

    # 5. Normalize to [0, 1]
    normalized = sharpened.astype(np.float32) / 255.0

    # 6. Image Augmentation (Random flips, rotation, etc.)
    if augment:
        augmented = augment_image(normalized)
    else:
        augmented = normalized

    # 7. Convert to grayscale (optional for some tasks)
    grayscale = cv2.cvtColor(augmented, cv2.COLOR_RGB2GRAY)

    # 8. Optional: Skip thresholding to avoid black image issues (only if unnecessary for your task)
    # 9. Morphological Operations (Erosion + Dilation) on grayscale or original image
    kernel = np.ones((3, 3), np.uint8)
    morph = cv2.morphologyEx(augmented, cv2.MORPH_CLOSE, kernel)  # Closing (dilate + erode)

    # Ensure the image stays in a usable color range
    final_image = np.clip(morph, 0, 1)  # Clamp values between 0 and 1

    return final_image

# %%
def augment_image(image):
    """
    Applies random augmentations such as flips and rotations to the image.
    
    Parameters:
        image (numpy array): Input image.
        
    Returns:
        augmented_image (numpy array): Augmented image.
    """
    # Random scaling factor between 0.8 and 1.2 (80% to 120%)
    scale_factor = random.uniform(0.8, 1.2)
    
    # Get the new dimensions based on the scaling factor
    new_width = int(image.shape[1] * scale_factor)
    new_height = int(image.shape[0] * scale_factor)
    
    # Resize image using the new dimensions
    scaled_image = cv2.resize(image, (new_width, new_height))
    # Optionally, resize it back to the target size (if needed)
    scaled_image = cv2.resize(scaled_image, (image.shape[1], image.shape[0]))


    return  scaled_image

# %%
# Load image (from previous step)
image_path = os.path.join(image_dir, 'BikesHelmets719.png')
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Preprocess image (including augmentation and all other steps)
processed = preprocess_image(image)

# Show the processed image
import matplotlib.pyplot as plt

plt.imshow(processed)  # Display in RGB format
plt.title("Processed Image")
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def segment_image_thresholding(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    gray_8bit = (gray * 255).astype(np.uint8)
    _, thresholded = cv2.threshold(gray_8bit, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    kernel = np.ones((5, 5), np.uint8)
    morph = cv2.morphologyEx(thresholded, cv2.MORPH_CLOSE, kernel)
    return morph

def segment_image_canny(image, low_threshold=100, high_threshold=200):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    gray_8bit = np.uint8(gray * 255)
    edges = cv2.Canny(gray_8bit, low_threshold, high_threshold)
    kernel = np.ones((5, 5), np.uint8)
    morph = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)
    return morph

def segment_image_sobel(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    magnitude = cv2.magnitude(sobel_x, sobel_y)
    return np.uint8(np.absolute(magnitude))

# 5. Region-based (Watershed)
def segment_with_watershed(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    gray = np.uint8(gray * 255)
    ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)
    sure_bg = cv2.dilate(opening, kernel, iterations=3)
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    ret, sure_fg = cv2.threshold(dist_transform, 0.7 * dist_transform.max(), 255,0)
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)
    ret, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0
    image_bgr = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    markers = cv2.watershed(image_bgr, markers)
    image_bgr[markers == -1] = [255, 0, 0]
    return cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# 6. Clustering (K-means)
def segment_with_kmeans(image, K=3):
    Z = image.reshape((-1, 3))
    Z = np.float32(Z)
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
    _, label, center = cv2.kmeans(Z, K, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
    center = np.uint8(center)
    res = center[label.flatten()]
    segmented_image = res.reshape(image.shape)
    return segmented_image
    # Example usage
image_path = os.path.join(image_dir, 'BikesHelmets719.png')
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

processed_image = preprocess_image(image)

# Apply desired method
#segmented = segment_image_thresholding(processed_image)
# segmented = segment_image_canny(processed_image)
# segmented = segment_image_sobel(processed_image)

#plt.imshow(segmented, cmap='gray')
#plt.axis('off')
#plt.title("Segmented Image")
#plt.show()

# %%
methods = {
    "Thresholding": segment_image_thresholding,
    "Canny Edge": segment_image_canny,
    "Sobel Edge": segment_image_sobel,
    #"Watershed": segment_with_watershed,
    "K-means Clustering": segment_with_kmeans
}
for name, method in methods.items():
    result = method(processed_image)
    plt.figure()
    plt.imshow(result, cmap='gray' if len(result.shape) == 2 else None)
    plt.title(f"{name} Segmentation")
    plt.axis('off')
plt.show()

# %%
from skimage.feature import hog
from skimage import exposure
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
import os
# ---------- HOG Feature Extraction ----------
def extract_hog_features(image):
    """
    Extracts Histogram of Oriented Gradients (HOG) features from an image.
    
    Parameters:
        image (numpy array): The input image (can be grayscale or color).
    
    Returns:
        features (numpy array): The HOG feature vector.
        hog_image (numpy array): The image representation of HOG features.
    """
    # Check if the image is already in grayscale
    if len(image.shape) == 3:  # RGB or BGR image
        gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    else:
        gray = image  # Already grayscale
    
    # Extract HOG features with more complete parameters
    features, hog_image = hog(gray, 
                            orientations=9,  # Number of orientation bins
                            pixels_per_cell=(8, 8), 
                            cells_per_block=(2, 2),
                            visualize=True)
    return features, hog_image  # Fixed variable name

# %%
# Example usage
image_path = os.path.join(image_dir, 'BikesHelmets719.png')  # Replace with actual image path
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Preprocess the image first
processed_image = preprocess_image(image)

# Extract HOG features from the processed image
hog_features, hog_image = extract_hog_features(processed_image)

# Display the HOG image
plt.imshow(hog_image, cmap='gray')
plt.title("HOG Features")
plt.axis('off')
plt.show()

# %%
def extract_color_histogram(image):
    """
    Extracts a normalized color histogram from the image.
    
    Parameters:
        image (numpy array): Input image.
        
    Returns:
        color_hist (numpy array): Normalized color histogram.
    """
    # Convert the image to HSV (Hue, Saturation, Value)
    hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    
    # Compute histogram for each channel (Hue, Saturation, and Value)
    hist_hue = cv2.calcHist([hsv_image], [0], None, [256], [0, 256])
    hist_saturation = cv2.calcHist([hsv_image], [1], None, [256], [0, 256])
    hist_value = cv2.calcHist([hsv_image], [2], None, [256], [0, 256])
    # Normalize the histograms
    hist_hue /= hist_hue.sum()
    hist_saturation /= hist_saturation.sum()
    hist_value /= hist_value.sum()
    
    # Combine histograms into one feature vector
    color_hist = np.concatenate((hist_hue.flatten(), hist_saturation.flatten(), hist_value.flatten()))
    
    return color_hist

# %%
# Example usage
color_histogram = extract_color_histogram(processed_image)

# Display color histogram
plt.plot(color_histogram[:256], color='r', label='Hue')
plt.plot(color_histogram[256:512], color='g', label='Saturation')
plt.plot(color_histogram[512:], color='b', label='Value')
plt.title("Color Histogram")
plt.legend()
plt.show()

# Features for training/ML
print("Color Histogram Length:", len(color_histogram))
# Out:
# Color Histogram Length: 768

# %%
def extract_features_from_segmented_image(segmented_image, original_image, min_region_area=100):
    """
    Extracts features from each segmented region, filtering tiny regions.
    """
    gray = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2GRAY) if len(segmented_image.shape) == 3 else segmented_image.copy()
    contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    features_list = []
    
    for contour in contours:
        # Skip small regions
        if cv2.contourArea(contour) < min_region_area:
            continue
        
        # Extract ROI
        mask = np.zeros_like(gray)
        cv2.drawContours(mask, [contour], -1, 255, cv2.FILLED)
        roi = cv2.bitwise_and(original_image, original_image, mask=mask)
        
        # Resize ROI for consistent HOG features
        roi_resized = cv2.resize(roi, (64, 128))  # Standard size for HOG
        
        # Extract features
         # Resize ROI for consistent HOG features
        roi_resized = cv2.resize(roi, (64, 128))  # Standard size for HOG
        # ✅ Skip empty (black) regions
        if np.count_nonzero(roi_resized) == 0:
            continue
            
        hog_features, _ = extract_hog_features(roi_resized)
        color_hist = extract_color_histogram(roi_resized)
        
        # Combine (should be ~2,500 features)
        combined_features = np.concatenate([hog_features, color_hist])
        features_list.append(combined_features)
    
    return features_list
    # Example usage
segmented_image = segment_image_canny(processed_image)
features = extract_features_from_segmented_image(segmented_image, processed_image)

print(f"Extracted features from {len(features)} regions:")
for i, feature in enumerate(features):
    print(f"Region {i+1}: {len(feature)} features")
# Out:
# Extracted features from 3 regions:
# Region 1: 4548 features
# Region 2: 4548 features
# Region 3: 4548 features

# %%
import os
import cv2
import numpy as np
import xml.etree.ElementTree as ET
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import (accuracy_score, precision_score, 
                           recall_score, f1_score, 
                           confusion_matrix, classification_report)

def parse_annotation(xml_path):
    """Parse XML annotation file and return boxes and labels."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    boxes, labels = [], []
    for obj in root.findall('object'):
        label = obj.find('name').text.lower()  # Convert to lowercase for consistency
        bbox = obj.find('bndbox')
        xmin = int(bbox.find('xmin').text)
        ymin = int(bbox.find('ymin').text)
        xmax = int(bbox.find('xmax').text)
        ymax = int(bbox.find('ymax').text)
        boxes.append([xmin, ymin, xmax, ymax])
        labels.append(label)
    return boxes, labels

def extract_features_from_annotations(image_dir, annotation_dir):
    """Extract features from all annotated images."""
    features, labels = [], []
    label_mapping = {
        'with_helmet': 1,
        'without_helmet': 0,
        'with helmet': 1,     # Handle spaces
        'without helmet': 0   # Handle spaces
    }
    for xml_file in os.listdir(annotation_dir):
        if not xml_file.endswith('.xml'):
            continue
            
        xml_path = os.path.join(annotation_dir, xml_file)
        image_name = xml_file.replace('.xml', '.png')
        image_path = os.path.join(image_dir, image_name)
        
        # Load and validate image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Warning: Could not load image {image_path}")
            continue
            
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        boxes, box_labels = parse_annotation(xml_path)
        
        for box, label in zip(boxes, box_labels):
            xmin, ymin, xmax, ymax = box
            roi = image[ymin:ymax, xmin:xmax]
             # Skip empty or too small regions
            if roi.size == 0 or min(roi.shape[:2]) < 10:
                continue
                
            try:
                # Process and extract features
                processed_roi = preprocess_image(roi)
                hog_features, _ = extract_hog_features(processed_roi)
                color_hist = extract_color_histogram(processed_roi)
                
                # Map label to numerical value
                numerical_label = label_mapping.get(label.lower(), 0)  # Default to 0 if unknown
                
                features.append(np.concatenate([hog_features, color_hist]))
                labels.append(numerical_label)
            except Exception as e:
                print(f"Error processing {image_path}: {str(e)}")
                continue
    
    if not features:
        raise ValueError("No features were extracted. Check your dataset and annotations.")
    
    return np.array(features), np.array(labels)

# %%
def evaluate_model(y_true, y_pred):
    """Comprehensive model evaluation."""
    print("\n" + "="*40)
    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=['No Helmet', 'Helmet']))
    
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_true, y_pred)
    print(cm)
    
    print("\nKey Metrics:")
    print(f"Accuracy:  {accuracy_score(y_true, y_pred):.4f}")
    print(f"Precision: {precision_score(y_true, y_pred):.4f}")
    print(f"Recall:    {recall_score(y_true, y_pred):.4f}")
    print(f"F1 Score:  {f1_score(y_true, y_pred):.4f}")
    print("="*40 + "\n")
# Define paths
DATASET_DIR = '/kaggle/input/helmet-detection'
image_dir = os.path.join(DATASET_DIR, 'images')
annotation_dir = os.path.join(DATASET_DIR, 'annotations')

# Extract features
try:
    features, labels = extract_features_from_annotations(image_dir, annotation_dir)
    print(f"Extracted {len(features)} samples with {features.shape[1]} features each")
    print("Class distribution:", np.bincount(labels))


    pca = PCA(n_components=0.85)
    features_reduced = pca.fit_transform(features)
    print(f"Reduced from {features.shape[1]} to {features_reduced.shape[1]} features")

    # Split and train
    X_train, X_test, y_train, y_test = train_test_split(
        features_reduced, labels, test_size=0.2, random_state=42, stratify=labels
    )
    
    svm_model = make_pipeline(
        StandardScaler(),
        SVC(kernel='rbf', C=1.0, gamma='scale',class_weight='balanced')
    )
    svm_model.fit(X_train, y_train)
    
    print(f"Train Accuracy: {svm_model.score(X_train, y_train):.2f}")
    print(f"Test Accuracy: {svm_model.score(X_test, y_test):.2f}")

    print("\nTraining Set Performance:")
    y_train_pred = svm_model.predict(X_train)
    evaluate_model(y_train, y_train_pred)
    print("\nTest Set Performance:")
    y_test_pred = svm_model.predict(X_test)
    evaluate_model(y_test, y_test_pred)
except Exception as e:
    print(f"Pipeline failed: {str(e)}")
# Out:
# Extracted 1429 samples with 35364 features each
# Class distribution: [477 952]
# Reduced from 35364 to 826 features
# Train Accuracy: 1.00
# Test Accuracy: 0.66
#
# Training Set Performance:
#
# ========================================
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Helmet       0.99      1.00      1.00       382
#       Helmet       1.00      1.00      1.00       761
#
#     accuracy                           1.00      1143
#    macro avg       1.00      1.00      1.00      1143
# weighted avg       1.00      1.00      1.00      1143
#
#
# Confusion Matrix:
# [[382   0]
#  [  2 759]]
#
# Key Metrics:
# Accuracy:  0.9983
# Precision: 1.0000
# Recall:    0.9974
# F1 Score:  0.9987
# ========================================
#
#
# Test Set Performance:
#
# ========================================
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Helmet       0.49      0.18      0.26        95
#       Helmet       0.69      0.91      0.78       191
#
#     accuracy                           0.66       286
#    macro avg       0.59      0.54      0.52       286
# weighted avg       0.62      0.66      0.61       286
#
#
# Confusion Matrix:
# [[ 17  78]
#  [ 18 173]]
#
# Key Metrics:
# Accuracy:  0.6643
# Precision: 0.6892
# Recall:    0.9058
# F1 Score:  0.7828
# ========================================

# %%
# Example: building a simple CNN (replace with your training code)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax')  # 2 classes: Helmet / No Helmet
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model (replace X_train, y_train with your data)
# model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))

# %%
model.save("helmet_final_model.h5")

# %%
import os
print(os.listdir())
# Out:
# ['helmet_final_model.h5', 'helmet_final_model.keras', '.virtual_documents']

# %%
import os
print(os.listdir("/kaggle/input/my-test-images2"))
# Out:
# ['two.jpg']

# %%
image_path = "/kaggle/input/my-test-images2/two.jpg"
label, conf = predict_helmet(image_path)
print(f"Prediction: {label} (Confidence: {conf:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Prediction: Helmet (Confidence: 0.62)

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from PIL import Image

# 1. Load your trained model
model = load_model("helmet_final_model.h5")

# 2. Define class names (adjust according to your training labels)
class_names = ["No Helmet", "Helmet"]

# 3. Prediction function
def predict_helmet(img_path, img_size=(224, 224)):
    # Load and preprocess image
    img = Image.open(img_path).convert("RGB")
    img = img.resize(img_size)
    img_array = np.array(img).astype("float32") / 255.0
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img_array)
    predicted_class = np.argmax(preds, axis=1)[0]
    confidence = np.max(preds)

    return class_names[predicted_class], confidence

# 4. Example usage
image_path = "/kaggle/input/my-test-images2/two.jpg"
label, conf = predict_helmet(image_path)
print(f"Prediction: {label} (Confidence: {conf:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Prediction: Helmet (Confidence: 0.62)
